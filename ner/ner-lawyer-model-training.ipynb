# %% [markdown]
# In this notebook we build the anonomization NER model.

# %%
import os
import numpy as np
import pandas as pd 
from ast import literal_eval

#I created separate csv for both ng and bruk datasets
for name in ["ng","bruk"]:

    #simple csv
    csv_data = pd.DataFrame(columns=['id', 'tokens', 'ner_tags'])

    for file in os.listdir(f'/kaggle/input/ner-uk/data/{name}'):
        #check annotation files only - txt has the same name but different extension
        if file.endswith('.ann'):

            #just reading files
            ann_lines = []
            text = ''
            text_lines = []
            with open(os.path.join(f'/kaggle/input/ner-uk/data/{name}', file), 'r', encoding='utf-8') as ann_file:
                ann_lines = ann_file.readlines()
            with open(os.path.join(f'/kaggle/input/ner-uk/data/{name}', file[:-4] + '.txt'), 'r', encoding='utf-8') as txt_file:
                text_lines = txt_file.readlines()
            
            #quick fix to handle /n in bruk dataset
            for line in text_lines:
                if line == '\n':
                    text += ' SEPARATOR '
                text += line
            
            #parse and filter out only relevant entities
            entities = []
            for line in ann_lines:
                parts = line.strip().split('\t')
                if len(parts) < 4:
                    continue
                if parts[1] not in ["PERS", "LOC", "ORG"]:
                    continue
                entities.append(parts[1:])
            
            #get words from text
            words = text.split()
            
            #if no relevant entities, tag all as O
            if not entities:
                ner_tags = [6] * len(words)
                csv_row = {
                    'id': len(csv_data),
                    'tokens': words,
                    'ner_tags': ner_tags
                }
                csv_data.loc[len(csv_data)] = csv_row
                continue

            #align entities with words
            ner_tags = []
            file_offset = 0
            current_entity_index = 0
            

            for word in words:
                #quickfix for separator from above
                if word == 'SEPARATOR':
                    file_offset += 1
                    continue

                word_start = file_offset
                word_end = file_offset + len(word)
                # Check if the current word overlaps with the current entity (Also give +1 as there are signs like < or etc.)
                # We can also do check for end but for example in НКВД and НКВД-исти example its better to check only start to map correctly

                if int(entities[current_entity_index][1]) <= word_start + 1:
                    # if word is at the beginning of an entity or previous tag was O, it's a B- tag
                    if (ner_tags[-1] if ner_tags else None) == 'O' or word_start == int(entities[current_entity_index][1]) or word_start + 1 == int(entities[current_entity_index][1]):
                        ner_tags.append('B-' + entities[current_entity_index][0])
                    #else it's an I- tag
                    else:
                        ner_tags.append('I-' + entities[current_entity_index][0])

                    # If the word end surpasses the entity end, move to the next entity
                    if word_end >= int(entities[current_entity_index][2]):
                        current_entity_index += 1
                else:
                    ner_tags.append('O')
                
                #no need to continue if all entities are processed
                if current_entity_index == len(entities):
                    break

                file_offset += len(word) + 1  # +1 for the space
            
            #remove seperator tokens
            words = [word for word in words if word != 'SEPARATOR']

            #extend ner tags because we break after all entities are processed
            ner_tags.extend(['O']*(len(words)-len(ner_tags)))

            #validation checks
            ner_words = [word for words in entities for word in words[3].split()]

            if not len(ner_words) == len([words[i] for i in range(len(ner_tags)) if ner_tags[i] != 'O']):
                print(f"Mismatch between entity words and NER tags {file} : {len(ner_words)} vs {len([words[i] for i in range(len(ner_tags)) if ner_tags[i] != 'O'])}")
                continue

            if not len(entities) == sum(1 for tag in ner_tags if tag.startswith('B-')):
                print(f"Mismatch between entities and NER tags {file}   : {len(entities)} vs {sum(1 for tag in ner_tags if tag.startswith('B-'))}")
                continue
            
            #map ner tags to integers
            ner_tags_map = {
                'B-LOC': 0, 'B-ORG': 1, 'B-PERS': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PERS': 5, 'O': 6
            }

            #create csv row
            csv_row = {
                'id': len(csv_data),
                'tokens': words,
                'ner_tags': [ner_tags_map[tag] for tag in ner_tags]
            }
            # append to dataframe
            csv_data.loc[len(csv_data)] = csv_row

    #save to csv
    csv_data.to_csv(f'{name}_ner.csv', index=False)
# Out:
# Mismatch between entities and NER tags f5e3415a3653.ann   : 31 vs 30
# Mismatch between entity words and NER tags c5930ba45ebe.ann : 59 vs 55
# Mismatch between entity words and NER tags 3262eb989bd6.ann : 51 vs 52
# Mismatch between entity words and NER tags 5d3d7e0d5bae.ann : 51 vs 50
# Mismatch between entity words and NER tags 6d47a8c4d755.ann : 93 vs 94
# Mismatch between entity words and NER tags 6f6281133248.ann : 67 vs 63
# Mismatch between entity words and NER tags a4eee55da896.ann : 72 vs 71
# Mismatch between entities and NER tags a6b3166e4d3b.ann   : 13 vs 12
# Mismatch between entity words and NER tags 5a4b4498fe83.ann : 72 vs 74
# Mismatch between entity words and NER tags 6dd15465059a.ann : 32 vs 34
# Mismatch between entity words and NER tags 76b9b07172fb.ann : 44 vs 46
# Mismatch between entity words and NER tags ba4204adf371.ann : 83 vs 84
# Mismatch between entities and NER tags b9ea4aa52bae.ann   : 37 vs 36
# Mismatch between entities and NER tags 816a89664813.ann   : 38 vs 37
# Mismatch between entities and NER tags d81632a877d7.ann   : 23 vs 22
# Mismatch between entity words and NER tags 150446f83aa2.ann : 85 vs 82
# Mismatch between entity words and NER tags 7982679365fb.ann : 64 vs 66
# Mismatch between entity words and NER tags e37120a0aa66.ann : 68 vs 70
# Mismatch between entity words and NER tags c446d7d1cea2.ann : 62 vs 59
# Mismatch between entity words and NER tags 605667093f7b.ann : 64 vs 63
# Mismatch between entity words and NER tags 6ada9307320e.ann : 51 vs 50
# Mismatch between entity words and NER tags eed5beaf4033.ann : 80 vs 84
# Mismatch between entity words and NER tags 7516eb24dae3.ann : 20 vs 25
# Mismatch between entities and NER tags 5f0403bf5093.ann   : 25 vs 22
# Mismatch between entity words and NER tags 0e5456794c26.ann : 61 vs 64
# Mismatch between entities and NER tags 254bbb126618.ann   : 34 vs 30
# Mismatch between entity words and NER tags 348b96a54914.ann : 74 vs 77
# Mismatch between entity words and NER tags f2653a1e387d.ann : 38 vs 37
# Mismatch between entity words and NER tags c2a04d86bfb8.ann : 68 vs 64
# Mismatch between entities and NER tags 18dbbac93012.ann   : 20 vs 19
# Mismatch between entity words and NER tags 2ff4fbe3fcc4.ann : 70 vs 69
# Mismatch between entities and NER tags e9061171da9d.ann   : 25 vs 23
# Mismatch between entities and NER tags eb523e7caf23.ann   : 44 vs 43
# Mismatch between entities and NER tags 71a651d2dbec.ann   : 58 vs 56
# Mismatch between entities and NER tags 54e33e2bc8c9.ann   : 58 vs 57
# Mismatch between entities and NER tags 804f1f7b3cba.ann   : 23 vs 22
# Mismatch between entity words and NER tags dc1202fd9850.ann : 70 vs 68
# Mismatch between entities and NER tags 3d0ab8ae38cf.ann   : 79 vs 78
# Mismatch between entity words and NER tags cad2484c0cc8.ann : 53 vs 57
# Mismatch between entities and NER tags 5085bb95b51a.ann   : 22 vs 21
# Mismatch between entities and NER tags 8c7ec62e35ac.ann   : 79 vs 78
# Mismatch between entity words and NER tags 17d3d678df81.ann : 67 vs 65
# Mismatch between entities and NER tags c0f24f5d70e3.ann   : 72 vs 71

# %%
import ast
from datasets import load_dataset, Dataset, Features, ClassLabel, Value, Sequence
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification
import evaluate
from transformers import AutoTokenizer
from transformers import DataCollatorForTokenClassification
import evaluate
from seqeval.metrics import f1_score, precision_score, recall_score, accuracy_score

seqeval = evaluate.load("seqeval")
# Out:
# 2025-12-12 00:47:24.963576: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765500444.987859     221 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765500444.995453     221 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
import datasets

data_bruk = datasets.load_dataset('csv', data_files='/kaggle/working/bruk_ner.csv')
data_ng = datasets.load_dataset('csv', data_files='/kaggle/working/ng_ner.csv')
combined = datasets.concatenate_datasets([data_bruk['train'], data_ng['train']])
combined
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['id', 'tokens', 'ner_tags'],
#     num_rows: 517
# })

# %%
combined[0]
# Out:
# {'id': 0,
#  'tokens': "['Уже', 'точилися', 'розмови', ',', 'що', 'коли', 'донецькі', 'шахтарі', 'до', 'певного', 'часу', 'не', 'встигнуть', 'провести', 'необхідні', 'захисні', 'роботи', 'біля', 'підірваного', 'реактора', ',', 'станеться', 'ще', 'один', 'вибух', '.', 'Мені', 'як', 'активісту', 'профспілки', 'доводилося', 'добувати', 'квитки', 'на', 'виїзд', 'сім’ям', 'наших', 'співробітників', '.', 'Прийшов', 'одного', 'дня', 'на', 'залізничний', 'вокзал', 'до', 'кас', 'в', 'депутатському', 'залі', ',', 'а', 'там', '—', 'ніколи', 'більше', 'такого', 'не', 'бачив', '—', 'довжелезна', 'черга', 'з', 'одних', 'тільки', 'Героїв', 'Радянського', 'Союзу', '.', 'Всі', 'при', 'своїх', 'зірках', ',', 'у', 'декого', 'бачив', 'і', 'дві', 'зірки', 'Героя', '.', 'Вразило', ',', 'як', 'вони', 'матюкалися', 'між', 'собою', ',', 'доводячи', 'один', 'одному', ',', 'які', 'роди', 'військ', 'мають', 'більше', 'заслуг', 'у', 'перемозі', 'над', 'Гітлером', '.', 'Було', 'чимало', 'п’яних', '.', 'Гнітюче', 'враження', '.', 'Свою', 'сім’ю', 'відвіз', 'у', 'Вірменію', 'до', 'рідних', ',', 'а', 'сам', 'вирішив', 'їхати', 'до', 'Прип’яті', ',', 'щоб', 'написати', 'серію', 'матеріалів', '.', 'Тодішній', 'редактор', '«', 'Молоді', 'України', '»', 'Іван', 'Бокий', 'не', 'погоджувався', 'на', 'таке', 'моє', 'відрядження', '.', 'Мотив', ':', 'я', 'працюю', 'не', 'у', 'відділі', 'інформації', ',', 'не', 'у', 'відділі', 'промисловості', ',', 'а', 'у', 'відділі', 'сільської', 'молоді', ',', 'що', 'не', 'дотичний', 'до', 'атомної', 'тематики', '.', 'А', 'до', 'того', 'ж', ',', 'аргументом', 'у', 'відмові', 'служило', 'й', 'те', ',', 'що', 'вже', 'є', 'матеріали', 'звідти', ',', 'котрі', 'підготував', 'наш', 'журналіст', 'Юрій', 'Луканов', '(', 'теперішній', 'голова', 'незалежної', 'медіапрофспілки', ')', '.', 'Планував', 'я', 'десяток', 'матеріалів', 'з', 'фотознімками', '.', 'Та', 'сталося', 'так', ',', 'що', 'один', 'блокнот', 'з', 'нотатками', 'разом', 'з', 'посвідченням', 'і', 'фотоплівкою', ',', 'на', 'яку', 'знімав', 'другу', 'половину', 'відрядження', ',', 'випали', 'з', 'кишені', ',', 'коли', 'сідав', 'у', 'машину', '.', 'Посвідчення', 'мені', 'повернули', ',', 'а', 'блокнот', ',', 'як', 'сказали', ',', 'розмок', 'під', 'дощем', 'і', 'його', 'викинули', '.', 'Залишився', 'лише', 'один', 'з', 'блокнотів', ',', 'з', 'якого', 'зміг', 'підготувати', 'три', 'публікації', '.', 'Ще', 'коли', 'тільки', 'збирався', 'в', 'Чорнобиль', ',', 'для', 'себе', 'визначився', ',', 'що', 'гонорари', 'за', 'публікації', 'перерахую', 'в', 'фонд', 'ліквідації', 'наслідків', 'аварії', '.', 'Так', 'і', 'зробив', '.', 'Тоді', 'наша', 'касирка', ',', 'пам’ятаю', ',', 'дивувалася', ',', 'що', 'гонорар', 'великий', ':', 'зазвичай', 'це', 'була', 'сума', 'близько', '25', 'рублів', ',', 'а', 'це', 'нарахували', 'аж', '54', 'рублі', '.', 'То', 'була', 'надбавка', 'за', 'відрядження', 'у', 'небезпечний', 'район', '.', 'Про', 'небезпеку', 'знали', ',', 'але', 'що', 'то', 'за', 'біда', ',', 'яких', 'вона', 'масштабів', ',', 'якось', 'наші', 'голови', 'не', 'сприймали', '.', 'Багато', 'років', 'минуло', '.', 'Але', 'й', 'тепер', 'ніби', 'нізвідки', 'напливають', 'уривки', 'спогадів', 'тих', 'днів', '.', 'Люди', ',', 'які', 'під', 'час', 'ротації', 'виїжджали', 'з', 'зони', ',', 'були', 'ніби', 'сонні', '.', 'Свої', 'захисні', 'респіраторні', 'маски', ',', 'що', 'називали', 'пелюстками', ',', 'викидали', 'прямо', 'з', 'автобусів', '.', 'Цими', 'масками', 'були', 'засипані', 'всі', 'узбіччя', '…']",
#  'ner_tags': '[6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 2, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 0, 6, 6, 6, 6, 6, 6, 6, 6, 0, 6, 6, 6, 6, 6, 6, 6, 6, 6, 1, 4, 6, 2, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 2, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 0, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]'}

# %% [markdown]
# We keep only the person tags, because this is our main goal - to anonimize personal information.

# %%
allowed_tags = {2, 5, 6}

def preprocess(example):
    # Parse the strings into Python lists
    tokens = ast.literal_eval(example["tokens"])
    ner_tags = ast.literal_eval(example["ner_tags"])

    # Keep only allowed tags, set all others to 6 (O)
    ner_tags = [tag if tag in allowed_tags else 6 for tag in ner_tags]

    example["tokens"] = tokens
    example["ner_tags"] = ner_tags
    return example

cleaned = combined.map(preprocess)

# Inspect result
print(cleaned[0])
# Out:
# Map:   0%|          | 0/517 [00:00<?, ? examples/s]
# {'id': 0, 'tokens': ['Уже', 'точилися', 'розмови', ',', 'що', 'коли', 'донецькі', 'шахтарі', 'до', 'певного', 'часу', 'не', 'встигнуть', 'провести', 'необхідні', 'захисні', 'роботи', 'біля', 'підірваного', 'реактора', ',', 'станеться', 'ще', 'один', 'вибух', '.', 'Мені', 'як', 'активісту', 'профспілки', 'доводилося', 'добувати', 'квитки', 'на', 'виїзд', 'сім’ям', 'наших', 'співробітників', '.', 'Прийшов', 'одного', 'дня', 'на', 'залізничний', 'вокзал', 'до', 'кас', 'в', 'депутатському', 'залі', ',', 'а', 'там', '—', 'ніколи', 'більше', 'такого', 'не', 'бачив', '—', 'довжелезна', 'черга', 'з', 'одних', 'тільки', 'Героїв', 'Радянського', 'Союзу', '.', 'Всі', 'при', 'своїх', 'зірках', ',', 'у', 'декого', 'бачив', 'і', 'дві', 'зірки', 'Героя', '.', 'Вразило', ',', 'як', 'вони', 'матюкалися', 'між', 'собою', ',', 'доводячи', 'один', 'одному', ',', 'які', 'роди', 'військ', 'мають', 'більше', 'заслуг', 'у', 'перемозі', 'над', 'Гітлером', '.', 'Було', 'чимало', 'п’яних', '.', 'Гнітюче', 'враження', '.', 'Свою', 'сім’ю', 'відвіз', 'у', 'Вірменію', 'до', 'рідних', ',', 'а', 'сам', 'вирішив', 'їхати', 'до', 'Прип’яті', ',', 'щоб', 'написати', 'серію', 'матеріалів', '.', 'Тодішній', 'редактор', '«', 'Молоді', 'України', '»', 'Іван', 'Бокий', 'не', 'погоджувався', 'на', 'таке', 'моє', 'відрядження', '.', 'Мотив', ':', 'я', 'працюю', 'не', 'у', 'відділі', 'інформації', ',', 'не', 'у', 'відділі', 'промисловості', ',', 'а', 'у', 'відділі', 'сільської', 'молоді', ',', 'що', 'не', 'дотичний', 'до', 'атомної', 'тематики', '.', 'А', 'до', 'того', 'ж', ',', 'аргументом', 'у', 'відмові', 'служило', 'й', 'те', ',', 'що', 'вже', 'є', 'матеріали', 'звідти', ',', 'котрі', 'підготував', 'наш', 'журналіст', 'Юрій', 'Луканов', '(', 'теперішній', 'голова', 'незалежної', 'медіапрофспілки', ')', '.', 'Планував', 'я', 'десяток', 'матеріалів', 'з', 'фотознімками', '.', 'Та', 'сталося', 'так', ',', 'що', 'один', 'блокнот', 'з', 'нотатками', 'разом', 'з', 'посвідченням', 'і', 'фотоплівкою', ',', 'на', 'яку', 'знімав', 'другу', 'половину', 'відрядження', ',', 'випали', 'з', 'кишені', ',', 'коли', 'сідав', 'у', 'машину', '.', 'Посвідчення', 'мені', 'повернули', ',', 'а', 'блокнот', ',', 'як', 'сказали', ',', 'розмок', 'під', 'дощем', 'і', 'його', 'викинули', '.', 'Залишився', 'лише', 'один', 'з', 'блокнотів', ',', 'з', 'якого', 'зміг', 'підготувати', 'три', 'публікації', '.', 'Ще', 'коли', 'тільки', 'збирався', 'в', 'Чорнобиль', ',', 'для', 'себе', 'визначився', ',', 'що', 'гонорари', 'за', 'публікації', 'перерахую', 'в', 'фонд', 'ліквідації', 'наслідків', 'аварії', '.', 'Так', 'і', 'зробив', '.', 'Тоді', 'наша', 'касирка', ',', 'пам’ятаю', ',', 'дивувалася', ',', 'що', 'гонорар', 'великий', ':', 'зазвичай', 'це', 'була', 'сума', 'близько', '25', 'рублів', ',', 'а', 'це', 'нарахували', 'аж', '54', 'рублі', '.', 'То', 'була', 'надбавка', 'за', 'відрядження', 'у', 'небезпечний', 'район', '.', 'Про', 'небезпеку', 'знали', ',', 'але', 'що', 'то', 'за', 'біда', ',', 'яких', 'вона', 'масштабів', ',', 'якось', 'наші', 'голови', 'не', 'сприймали', '.', 'Багато', 'років', 'минуло', '.', 'Але', 'й', 'тепер', 'ніби', 'нізвідки', 'напливають', 'уривки', 'спогадів', 'тих', 'днів', '.', 'Люди', ',', 'які', 'під', 'час', 'ротації', 'виїжджали', 'з', 'зони', ',', 'були', 'ніби', 'сонні', '.', 'Свої', 'захисні', 'респіраторні', 'маски', ',', 'що', 'називали', 'пелюстками', ',', 'викидали', 'прямо', 'з', 'автобусів', '.', 'Цими', 'масками', 'були', 'засипані', 'всі', 'узбіччя', '…'], 'ner_tags': [6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 2, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 2, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...

# %%
data = cleaned.train_test_split(test_size=0.2, seed=42)
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 413
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 104
#     })
# })

# %%
label_list = ['B-LOC', 'B-ORG', 'B-PERS', 'I-LOC', 'I-ORG', 'I-PERS', 'O']
print("Label list:", label_list)

id2label = {i: label for i, label in enumerate(label_list)}
print("\nid2label:")
for i, label in id2label.items():
    print(f"    {i}: \"{label}\",")

label2id = {label: i for i, label in enumerate(label_list)}
print("\nlabel2id:")
for label, i in label2id.items():
    print(f"    \"{label}\": {i},")
# Out:
# Label list: ['B-LOC', 'B-ORG', 'B-PERS', 'I-LOC', 'I-ORG', 'I-PERS', 'O']
#
# id2label:
#     0: "B-LOC",
#     1: "B-ORG",
#     2: "B-PERS",
#     3: "I-LOC",
#     4: "I-ORG",
#     5: "I-PERS",
#     6: "O",
#
# label2id:
#     "B-LOC": 0,
#     "B-ORG": 1,
#     "B-PERS": 2,
#     "I-LOC": 3,
#     "I-ORG": 4,
#     "I-PERS": 5,
#     "O": 6,

# %%
def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    average_method = "macro"
    results = {
        "f1": f1_score(true_labels, true_predictions, average=average_method),
        "precision": precision_score(true_labels, true_predictions, average=average_method),
        "recall": recall_score(true_labels, true_predictions, average=average_method),
        "accuracy": accuracy_score(true_labels, true_predictions),
    }
    return {
        "precision": results["precision"],
        "recall": results["recall"],
        "f1": results["f1"],
        "accuracy": results["accuracy"],
    }

# %%
def chunk_tokenize_and_align(examples,tokenizer, max_length=512):
    all_input_ids = []
    all_attention_masks = []
    all_labels = []

    for tokens, labels in zip(examples["tokens"], examples["ner_tags"]):
        tokenized = tokenizer(
            tokens,
            is_split_into_words=True,
            truncation=False,
            return_offsets_mapping=False,
        )

        word_ids = tokenized.word_ids()
        label_ids = []
        previous_word_idx = None

        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(labels[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx

        input_ids = tokenized["input_ids"]
        attention_mask = tokenized["attention_mask"]

        for i in range(0, len(input_ids), max_length):
            chunk_input_ids = input_ids[i:i + max_length]
            chunk_attention_mask = attention_mask[i:i + max_length]
            chunk_labels = label_ids[i:i + max_length]

            all_input_ids.append(chunk_input_ids)
            all_attention_masks.append(chunk_attention_mask)
            all_labels.append(chunk_labels)

    return {
        "input_ids": all_input_ids,
        "attention_mask": all_attention_masks,
        "labels": all_labels,
    }

# %% [markdown]
# We use xlm-roberta-base as itt performed the best in the homework task.

# %%
from datasets import Dataset, DatasetDict


dataset = data

tokenizer = AutoTokenizer.from_pretrained('xlm-roberta-base')

chunked_data = {}

for split_name in ["train", "test"]:
    all_input_ids = []
    all_attention_masks = []
    all_labels = []

    for example in dataset[split_name]:
        chunks = chunk_tokenize_and_align(
            {"tokens": [example["tokens"]], "ner_tags": [example["ner_tags"]]},
            tokenizer=tokenizer,
            max_length=512
        )

        all_input_ids.extend(chunks["input_ids"])
        all_attention_masks.extend(chunks["attention_mask"])
        all_labels.extend(chunks["labels"])

    chunked_data[split_name] = Dataset.from_dict({
        "input_ids": all_input_ids,
        "attention_mask": all_attention_masks,
        "labels": all_labels
    })

chunked_dataset = DatasetDict(chunked_data)
print(chunked_dataset)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1038 > 512). Running this sequence through the model will result in indexing errors
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 1006
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 276
#     })
# })

# %%
def train_and_evaluate_model(model_name, data, tokenizer):
    local_data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

    model = AutoModelForTokenClassification.from_pretrained(
        model_name,
        num_labels=len(label_list),
        id2label=id2label,
        label2id=label2id,
        trust_remote_code=True
    )
    
    args = TrainingArguments(
        output_dir=f"./results/{model_name.replace('/', '_')}",
        
        num_train_epochs=6,
        eval_strategy="epoch",
        save_strategy="epoch",
        
        learning_rate=2e-5,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=4,
        gradient_accumulation_steps=4,
        weight_decay=0.01,
        
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        greater_is_better=True,
        save_total_limit=1,
    
        logging_strategy="epoch",
        report_to="none",
        push_to_hub=False
    )

    trainer = Trainer(
        model=model,
        args=args,
        train_dataset=data["train"],
        eval_dataset=data["test"],
        tokenizer=tokenizer,
        data_collator=local_data_collator,
        compute_metrics=compute_metrics
    )

    trainer.train()
    eval_results = trainer.evaluate()
    return eval_results['eval_f1']

# %%
print(train_and_evaluate_model('xlm-roberta-base', chunked_dataset, tokenizer))
# Out:
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /tmp/ipykernel_221/3634384742.py:35: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='192' max='192' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [192/192 08:26, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.343400</td>
#       <td>0.064285</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.973298</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.041200</td>
#       <td>0.018104</td>
#       <td>0.876281</td>
#       <td>0.908497</td>
#       <td>0.892098</td>
#       <td>0.995750</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.014200</td>
#       <td>0.010245</td>
#       <td>0.938161</td>
#       <td>0.941993</td>
#       <td>0.940073</td>
#       <td>0.997707</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.007900</td>
#       <td>0.008796</td>
#       <td>0.944992</td>
#       <td>0.940359</td>
#       <td>0.942670</td>
#       <td>0.997803</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.006600</td>
#       <td>0.008366</td>
#       <td>0.948361</td>
#       <td>0.945261</td>
#       <td>0.946809</td>
#       <td>0.997995</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.005800</td>
#       <td>0.008484</td>
#       <td>0.948887</td>
#       <td>0.940359</td>
#       <td>0.944604</td>
#       <td>0.997947</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     <div>
#
#       <progress value='69' max='69' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [69/69 00:04]
#     </div>
# 0.9468085106382979

# %% [markdown]
# Performs fairly good on general data. Lets test on artificial test cases.

# %% [markdown]
# Here we load the data from deanon notebook, where we prepared the test cases.

# %%
import json
import re
import csv

def process_json_to_csv(json_file_path, csv_file_path):
    try:
        with open(json_file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: The file '{json_file_path}' was not found.")
        return
    except json.JSONDecodeError:
        print(f"Error: Could not decode JSON from '{json_file_path}'.")
        return
    except Exception as e:
        print(f"An error occurred while reading the JSON file: {e}")
        return

    token_regex = re.compile(r"[\w'-]+|[^\w\s]", re.UNICODE)

    try:
        with open(csv_file_path, 'w', encoding='utf-8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['tokens', 'ner_tags'])

            for item in data:
                original_text = item.get('text', '')
                entities = item.get('generated_entities', [])

                entity_map = {
                    e['start']: e['text']
                    for e in entities
                    if 'start' in e and 'text' in e
                }

                final_tokens = []
                final_ner_tags = []

                for match in token_regex.finditer(original_text):
                    token_text = match.group(0)
                    token_start = match.start()

                    if token_start in entity_map:
                        full_name = entity_map[token_start]
                        name_parts = full_name.split()

                        if len(name_parts) == 3:
                            final_tokens.extend(name_parts)
                            final_ner_tags.extend([2, 5, 5])
                        else:
                            print(f"Warning: Entity '{full_name}' at char {token_start} did not have 3 words. Skipping replacement, tagging as 'O'.")
                            final_tokens.append(token_text)
                            final_ner_tags.append(6)
                    else:

                        final_tokens.append(token_text)
                        final_ner_tags.append(6)

                writer.writerow([str(final_tokens), str(final_ner_tags)])

        print(f"Successfully processed data and saved to '{csv_file_path}'")

    except IOError:
        print(f"Error: Could not write to CSV file '{csv_file_path}'.")
    except Exception as e:
        print(f"An error occurred during processing: {e}")

# %%
process_json_to_csv("/kaggle/input/test-deacon/first_50_rows_anonymized.json", "test.csv")
# Out:
# Warning: Entity 'Кравченко' at char 6574 did not have 3 words. Skipping replacement, tagging as 'O'.
# Successfully processed data and saved to 'test.csv'

# %%
test_ds = datasets.load_dataset('csv', data_files='/kaggle/working/test.csv')
test_ds = test_ds['train']
test_ds = test_ds.map(preprocess)
test_ds[0]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/50 [00:00<?, ? examples/s]
# {'tokens': ['УХВАЛА',
#   '30',
#   'листопада',
#   '2023',
#   'року',
#   'м',
#   '.',
#   'Київ',
#   'справа',
#   '№',
#   '296',
#   '/',
#   '5017',
#   '/',
#   '18',
#   'провадження',
#   '№',
#   '61-14884ск23',
#   'Верховний',
#   'Суд',
#   'у',
#   'складі',
#   'колегії',
#   'суддів',
#   'Третьої',
#   'судової',
#   'палати',
#   'Касаційного',
#   'цивільного',
#   'суду',
#   ':',
#   'Ігнатенка',
#   'В',
#   '.',
#   'М',
#   '.',
#   '(',
#   'суддя-доповідач',
#   ')',
#   ',',
#   'Карпенко',
#   'С',
#   '.',
#   'О',
#   '.',
#   ',',
#   'Фаловської',
#   'І',
#   '.',
#   'М',
#   '.',
#   ',',
#   'розглянув',
#   'клопотання',
#   'приватного',
#   'акціонерного',
#   'товариства',
#   '«',
#   'Вібросепаратор',
#   '»',
#   'про',
#   'зупинення',
#   'виконання',
#   'рішення',
#   'Корольовського',
#   'районного',
#   'суду',
#   'м',
#   '.',
#   'Житомира',
#   'від',
#   '18',
#   'лютого2022',
#   'року',
#   'та',
#   'постанови',
#   'Житомирського',
#   'апеляційного',
#   'суду',
#   'від',
#   '04',
#   'жовтня',
#   '2023',
#   'року',
#   'в',
#   'справі',
#   'за',
#   'позовом',
#   'Савченка',
#   'Євгенія',
#   'Степановича',
#   'до',
#   'приватного',
#   'акціонерного',
#   'товариства',
#   '«',
#   'Вібросепаратор',
#   '»',
#   ',',
#   'треті',
#   'особи',
#   ':',
#   'фізична',
#   'особа',
#   '-',
#   'підприємець',
#   'Гриневич',
#   'Данило',
#   'Олександрович',
#   ',',
#   'товариство',
#   'з',
#   'обмеженою',
#   'відповідальністю',
#   '«',
#   'НТК',
#   'Степ',
#   '»',
#   ',',
#   'про',
#   'стягнення',
#   'упущеної',
#   'вигоди',
#   'та',
#   'відшкодування',
#   'моральної',
#   'шкоди',
#   ',',
#   'ВСТАНОВИВ',
#   ':',
#   'У',
#   'травні',
#   '2018',
#   'року',
#   'Савченко',
#   'Євгеній',
#   'Степанович',
#   'звернувся',
#   'до',
#   'суду',
#   'з',
#   'позовом',
#   'до',
#   'приватного',
#   'акціонерного',
#   'товариства',
#   '«',
#   'Вібросепаратор',
#   '»',
#   '(',
#   'далі',
#   '-',
#   'ПрАТ',
#   '«',
#   'Вібросепаратор',
#   '»',
#   ')',
#   ',',
#   'треті',
#   'особи',
#   ':',
#   'фізична',
#   'особа',
#   '-',
#   'підприємець',
#   'Гриневич',
#   'Данило',
#   'Олександрович',
#   '(',
#   'далі',
#   '-',
#   'ФОП',
#   'Гриневич',
#   'Данило',
#   'Олександрович',
#   ')',
#   ',',
#   'товариство',
#   'з',
#   'обмеженою',
#   'відповідальністю',
#   '«',
#   'НТК',
#   'Степ',
#   '»',
#   ',',
#   'в',
#   'якому',
#   ',',
#   'з',
#   'урахуванням',
#   'заяви',
#   'про',
#   'збільшення',
#   'позовних',
#   'вимог',
#   ',',
#   'просив',
#   'стягнути',
#   'з',
#   'відповідача',
#   'упущену',
#   'вигоду',
#   'в',
#   'розмірі',
#   '553',
#   '297',
#   ',',
#   '32',
#   'грн',
#   'та',
#   'моральну',
#   'шкоду',
#   'у',
#   'розмірі',
#   '800',
#   '000',
#   ',',
#   '00',
#   'грн',
#   '.',
#   'Рішенням',
#   'Корольовського',
#   'районного',
#   'суду',
#   'м',
#   '.',
#   'Житомира',
#   'від',
#   '18',
#   'лютого',
#   '2022',
#   'року',
#   'позов',
#   'задоволено',
#   'частково',
#   '.',
#   'Стягнено',
#   'з',
#   'ПрАТ',
#   '«',
#   'Вібросепаратор',
#   '»',
#   'на',
#   'користь',
#   'Савченкові',
#   'Євгенію',
#   'Степановичу',
#   'на',
#   'відшкодування',
#   'упущеної',
#   'вигоди',
#   '299',
#   '594',
#   ',',
#   '39',
#   'грн',
#   'та',
#   'на',
#   'відшкодування',
#   'моральної',
#   'шкоди',
#   '300',
#   '000',
#   ',',
#   '00',
#   'грн',
#   ',',
#   'а',
#   'всього',
#   '599',
#   '594',
#   ',',
#   '00',
#   'грн',
#   '.',
#   'Постановою',
#   'Житомирського',
#   'апеляційного',
#   'суду',
#   'від',
#   '04',
#   'жовтня',
#   '2023',
#   'року',
#   'апеляційну',
#   'скаргу',
#   'Савченка',
#   'Євгенія',
#   'Степановича',
#   'залишено',
#   'без',
#   'задоволення',
#   ',',
#   'апеляційну',
#   'скаргу',
#   'ПрАТ',
#   '«',
#   'Вібросепаратор',
#   '»',
#   'задоволено',
#   'частково',
#   '.',
#   'Рішення',
#   'Корольовського',
#   'районного',
#   'суду',
#   'м',
#   '.',
#   'Житомира',
#   'від',
#   '18',
#   'лютого',
#   '2022',
#   'року',
#   'в',
#   'частині',
#   'відшкодування',
#   'моральної',
#   'шкоди',
#   'змінено',
#   ',',
#   'зменшено',
#   'суму',
#   ',',
#   'яка',
#   'підлягає',
#   'стягненню',
#   'з',
#   'ПрАТ',
#   '«',
#   'Вібросепаратор',
#   '»',
#   'на',
#   'користь',
#   'Савченкові',
#   'Євгенію',
#   'Степановичу',
#   ',',
#   'з',
#   '300',
#   '000',
#   ',',
#   '00',
#   'грн',
#   'до',
#   '100',
#   '000',
#   ',',
#   '00',
#   'грн',
#   ',',
#   'а',
#   'також',
#   'загальну',
#   'суму',
#   'стягнення',
#   'з',
#   '599',
#   '594',
#   ',',
#   '00',
#   'грн',
#   'до',
#   '399',
#   '594',
#   ',',
#   '00',
#   'грн',
#   '.',
#   'У',
#   'решті',
#   'рішеннясуду',
#   'першої',
#   'інстанції',
#   'залишено',
#   'без',
#   'змін',
#   '.',
#   'Вирішено',
#   'питання',
#   'про',
#   'розподіл',
#   'судових',
#   'витрат',
#   '.',
#   '18',
#   'жовтня',
#   '2023',
#   'року',
#   'ПрАТ',
#   '«',
#   'Вібросепаратор',
#   '»',
#   'звернулося',
#   'до',
#   'Верховного',
#   'Суду',
#   'з',
#   'касаційною',
#   'скаргою',
#   'на',
#   'рішення',
#   'Корольовського',
#   'районного',
#   'суду',
#   'м',
#   '.',
#   'Житомира',
#   'від',
#   '18',
#   'лютого',
#   '2022',
#   'року',
#   'та',
#   'постанову',
#   'Житомирського',
#   'апеляційного',
#   'суду',
#   'від',
#   '04',
#   'жовтня',
#   '2023',
#   'року',
#   '.',
#   'У',
#   'касаційній',
#   'скарзі',
#   'відповідач',
#   'просить',
#   'суд',
#   'касаційної',
#   'інстанції',
#   'скасувати',
#   'вказані',
#   'судові',
#   'рішення',
#   'та',
#   'ухвалити',
#   'нове',
#   'судове',
#   'рішення',
#   'про',
#   'відмову',
#   'у',
#   'задоволенні',
#   'позову',
#   '.',
#   'Ухвалою',
#   'Верховного',
#   'Суду',
#   'від',
#   '26',
#   'жовтня',
#   '2023',
#   'року',
#   'відкрито',
#   'касаційне',
#   'провадження',
#   'за',
#   'касаційною',
#   'скаргою',
#   'ПрАТ',
#   '«',
#   'Вібросепаратор',
#   '»',
#   ',',
#   'витребувано',
#   'справу',
#   'із',
#   'суду',
#   'першої',
#   'інстанції',
#   ',',
#   'відмовлено',
#   'у',
#   'задоволенні',
#   'клопотання',
#   'про',
#   'зупинення',
#   'виконання',
#   'рішення',
#   'Корольовського',
#   'районного',
#   'суду',
#   'м',
#   '.',
#   'Житомира',
#   'від',
#   '18',
#   'лютого',
#   '2022',
#   'року',
#   'та',
#   'постанови',
#   'Житомирського',
#   'апеляційного',
#   'суду',
#   'від',
#   '04',
#   'жовтня',
#   '2023',
#   'року',
#   '.',
#   '17',
#   'листопада',
#   '2023',
#   'року',
#   'ПрАТ',
#   '«',
#   'Вібросепаратор',
#   '»',
#   'звернулося',
#   'до',
#   'Верховного',
#   'Суду',
#   'з',
#   'клопотанням',
#   'про',
#   'зупинення',
#   'виконання',
#   'рішення',
#   'Корольовського',
#   'районного',
#   'суду',
#   'м',
#   '.',
#   'Житомира',
#   'від',
#   '18',
#   'лютого',
#   '2022',
#   'року',
#   'та',
#   'постанови',
#   'Житомирського',
#   'апеляційного',
#   'суду',
#   'від',
#   '04',
#   'жовтня',
#   '2023',
#   'року',
#   ',',
#   'яке',
#   'обґрунтоване',
#   'тим',
#   ',',
#   'що',
#   'постановою',
#   'головного',
#   'державного',
#   'виконавця',
#   'Корольовського',
#   'відділу',
#   'державної',
#   'виконавчої',
#   'служби',
#   'у',
#   'місті',
#   'Житомирі',
#   'Центрально-Західного',
#   'міжрегіонального',
#   'управління',
#   'Міністерства',
#   'юстиції',
#   '(',
#   'м',
#   '.',
#   'Хмельницький',
#   ')',
#   'від',
#   '06',
#   'вересня',
#   '2022',
#   'року',
#   'відкрито',
#   'виконавче',
#   'провадження',
#   '№',
#   'НОМЕР_1',
#   'на',
#   'підставі',
#   'виконавчого',
#   'листа',
#   '№',
#   '296',
#   '/',
#   '5017',
#   '/',
#   '18',
#   ',',
#   'виданого',
#   '27',
#   'липня',
#   '2022',
#   'року',
#   'Корольовським',
#   'районним',
#   'судом',
#   'м',
#   '.',
#   'Житомира',
#   '.',
#   'Крім',
#   'того',
#   ',',
#   'під',
#   'час',
#   'здійснення',
#   'виконавчого',
#   'провадження',
#   'накладено',
#   'арешт',
#   'на',
#   'нерухоме',
#   'майно',
#   'боржника',
#   '.',
#   'Вказує',
#   ',',
#   'що',
#   'майно',
#   'боржника',
#   'може',
#   'бути',
#   'реалізоване',
#   'і',
#   'здійснено',
#   'стягнення',
#   'на',
#   'грошові',
#   'кошти',
#   'до',
#   'закінчення',
#   'перегляду',
#   'справи',
#   'касаційним',
#   'судом',
#   ',',
#   'а',
#   'у',
#   'випадку',
#   'скасування',
#   'оскаржуваних',
#   'судових',
#   'рішень',
#   'неможливо',
#   'буде',
#   'здійснити',
#   'поворот',
#   'виконання',
#   'рішень',
#   '.',
#   'Клопотання',
#   'підлягає',
#   'задоволенню',
#   'з',
#   'таких',
#   'підстав',
#   '.',
#   'Відповідно',
#   'до',
#   'частини',
#   'восьмої',
#   'статті',
#   '394',
#   'Цивільного',
#   'процесуального',
#   'кодексу',
#   '(',
#   'далі',
#   '-',
#   'ЦПК',
#   ')',
#   'за',
#   'наявності',
#   'клопотання',
#   'особи',
#   ',',
#   'яка',
#   'подала',
#   'касаційну',
#   'скаргу',
#   ',',
#   'суд',
#   'у',
#   'разі',
#   'необхідності',
#   'вирішує',
#   'питання',
#   'про',
#   'зупинення',
#   'виконання',
#   'рішення',
#   '(',
#   'ухвали',
#   ')',
#   'суду',
#   'або',
#   'зупинення',
#   'його',
#   'дії',
#   '.',
#   'Відповідно',
#   'до',
#   'частини',
#   'першої',
#   'статті',
#   '436',
#   'ЦПК',
#   'України',
#   'суд',
#   'касаційної',
#   'інстанції',
#   'за',
#   'заявою',
#   'учасника',
#   'справи',
#   'або',
#   'за',
#   'своєю',
#   'ініціативою',
#   'може',
#   'зупинити',
#   'виконання',
#   'оскарженого',
#   'рішення',
#   'суду',
#   'або',
#   'зупинити',
#   'його',
#   'дію',
#   '(',
#   'якщо',
#   'рішення',
#   'не',
#   'передбачає',
#   'примусового',
#   'виконання',
#   ')',
#   'до',
#   'закінчення',
#   'його',
#   'перегляду',
#   'в',
#   'касаційному',
#   'порядку',
#   '.',
#   'Верховний',
#   'Суд',
#   'виходить',
#   'із',
#   'того',
#   ',',
#   'що',
#   'клопотання',
#   '(',
#   'заява',
#   ')',
#   'про',
#   'зупинення',
#   'виконання',
#   '(',
#   'дії',
#   ')',
#   'судових',
#   'рішень',
#   'має',
#   'бути',
#   'мотивованим',
#   ',',
#   'містити',
#   'підстави',
#   'для',
#   'зупинення',
#   'виконання',
#   'судових',
#   'рішень',
#   ',',
#   'підтверджені',
#   'доказами',
#   '.',
#   'Вирішуючи',
#   'питання',
#   'про',
#   'зупинення',
#   'виконання',
#   '(',
#   'дії',
#   ')',
#   'судового',
#   'рішення',
#   ',',
#   'суд',
#   'касаційної',
#   'інстанції',
#   'враховує',
#   'необхідність',
#   'у',
#   'цьому',
#   ',',
#   'зокрема',
#   'у',
#   'разі',
#   'ймовірності',
#   'утруднення',
#   'повторного',
#   'розгляду',
#   'справи',
#   'внаслідок',
#   'можливого',
#   'скасування',
#   'судового',
#   'рішення',
#   ',',
#   'забезпечення',
#   'збалансованості',
#   'інтересів',
#   'сторін',
#   ',',
#   'запобігання',
#   'порушенню',
#   'прав',
#   'осіб',
#   ',',
#   'які',
#   'брали',
#   'участь',
#   'у',
#   'справі',
#   ',',
#   'та',
#   'які',
#   'не',
#   'брали',
#   'такої',
#   'участі',
#   ',',
#   'але',
#   'рішенням',
#   'суду',
#   'вирішено',
#   'питання',
#   'про',
#   'їх',
#   'права',
#   ',',
#   'свободи',
#   'чи',
#   'обов',
#   '`',
#   'язки',
#   '.',
#   'Отже',
#   ',',
#   'метою',
#   'вирішення',
#   'питання',
#   'про',
#   'зупинення',
#   'виконання',
#   '(',
#   'дії',
#   ')',
#   'судового',
#   'рішення',
#   'є',
#   'недопущення',
#   'порушення',
#   'прав',
#   ',',
#   'свобод',
#   'та',
#   'охоронюваних',
#   'законом',
#   'інтересів',
#   'особи',
#   ',',
#   'яка',
#   'подала',
#   'касаційну',
#   'скаргу',
#   'та',
#   'інших',
#   'осіб',
#   ',',
#   'які',
#   'беруть',
#   'участь',
#   'у',
#   'справі',
#   ',',
#   'якщо',
#   'такі',
#   'наслідки',
#   'можуть',
#   'настати',
#   'у',
#   'зв',
#   '`',
#   'язку',
#   'з',
#   'виконанням',
#   '(',
#   'дією',
#   ')',
#   'судового',
#   'рішення',
#   '.',
#   'З',
#   'урахуванням',
#   'предмета',
#   'спору',
#   ',',
#   'змісту',
#   'оскаржуваних',
#   'судових',
#   'рішень',
#   'та',
#   'поданих',
#   'відповідачем',
#   'доказів',
#   ':',
#   'копії',
#   'постанови',
#   'про',
#   'відкриття',
#   'виконавчого',
#   'провадження',
#   'від',
#   '28',
#   'липня',
#   '2022',
#   'року',
#   '№',
#   'НОМЕР_1',
#   ',',
#   'копії',
#   'постанови',
#   'про',
#   'арешт',
#   'майна',
#   'боржника',
#   'від',
#   '28',
#   'липня',
#   '2022',
#   'року',
#   '№',
#   'НОМЕР_1',
#   ',',
#   'копії',
#   'постанови',
#   'про',
#   'зупинення',
#   'виконавчого',
#   'провадження',
#   'від',
#   '06',
#   'вересня',
#   '2022',
#   'року',
#   '№',
#   'НОМЕР_1',
#   ',',
#   'копії',
#   'постанови',
#   'про',
#   'поновлення',
#   'вчинення',
#   'виконавчих',
#   'дій',
#   'від',
#   '08',
#   'листопада',
#   '2023',
#   'року',
#   '№',
#   'НОМЕР_1',
#   ',',
#   'копії',
#   'постанови',
#   'про',
#   'арешт',
#   'коштів',
#   'боржника',
#   'від',
#   '09',
#   'листопада',
#   '2023',
#   'року',
#   '№',
#   'НОМЕР_1',
#   ',',
#   'касаційний',
#   'суд',
#   'дійшов',
#   'висновку',
#   'про',
#   ...],
#  'ner_tags': [6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   2,
#   5,
#   5,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   2,
#   5,
#   5,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   2,
#   5,
#   5,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   2,
#   5,
#   5,
#   6,
#   6,
#   6,
#   6,
#   2,
#   5,
#   5,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   2,
#   5,
#   5,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   2,
#   5,
#   5,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   2,
#   5,
#   5,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   6,
#   ...]}

# %%
def classify_text(tokens):
    all_word_predictions = []
    start_word = 0
    tokenizer.model_max_length = 512

    while start_word < len(tokens):
        tokenized = tokenizer(
            tokens[start_word:],
            is_split_into_words=True,
            truncation=True,
            max_length=512,
            return_tensors="pt",
        ).to(model.device)

        logits = model(**tokenized).logits
        predictions = torch.argmax(logits, dim=2)[0].tolist()
        word_ids = tokenized.word_ids(batch_index=0)

        chunk_word_preds = []
        previous_word_idx = None
        for i, word_idx in enumerate(word_ids):
            if word_idx is not None and word_idx != previous_word_idx:
                chunk_word_preds.append(predictions[i])
            previous_word_idx = word_idx

        all_word_predictions.extend(chunk_word_preds)

        last_word_idx = max([wid for wid in word_ids if wid is not None])
        start_word += last_word_idx + 1

    return all_word_predictions

# %%
import ast
import torch

MODEL_PATH="/kaggle/working/results/xlm-roberta-base/checkpoint-160/"

tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)
model = AutoModelForTokenClassification.from_pretrained(MODEL_PATH)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()




classify_text(["Американський", "президент", "Іван", "Трамп", "на", "тлі", "нового", "загострення", "торговельних", "відносин", "з", "Китаєм", "запевнив", "–", "все", "буде", "добре."])
# Out:
# [6, 6, 2, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]

# %%
def evaluate_model(test_dataset, classify_function):

    ner_metric = evaluate.load("seqeval")

    all_predictions = []
    all_true_labels = []

    print(f"Running inference on {len(test_dataset)} items...")

    for item in test_dataset:
        input_ids = item['tokens']
        true_label_ids = item['ner_tags']
        predicted_labels = classify_function(input_ids)
        
        predicted_labels_str = [id2label[pid] for pid in predicted_labels]
        all_predictions.append(predicted_labels_str)
        
        true_labels_cleaned = []
        for label_id in true_label_ids:
            if label_id != -100:
                true_labels_cleaned.append(id2label[label_id])
        
        all_true_labels.append(true_labels_cleaned)

    print("Inference complete. Calculating metrics...")

    results = ner_metric.compute(predictions=all_predictions, references=all_true_labels)
    
    return results

# %%
print(evaluate_model(test_ds, classify_text))
# Out:
# Running inference on 50 items...
# Inference complete. Calculating metrics...
# {'PERS': {'precision': 0.5228628230616302, 'recall': 0.8129829984544049, 'f1': 0.6364186327888687, 'number': 647}, 'overall_precision': 0.5228628230616302, 'overall_recall': 0.8129829984544049, 'overall_f1': 0.6364186327888687, 'overall_accuracy': 0.9744571204511082}

# %% [markdown]
# We get much worse results here but it is obvious why. We have great accuracy 0.97. Lets see at the false positives that our model decided to anonimize.

# %%
def evaluate_model(test_dataset, classify_function):

    ner_metric = evaluate.load("seqeval")

    all_predictions = []
    all_true_labels = []

    print(f"Running inference on {len(test_dataset)} items...")
    
    false_positive_log = []

    for idx, item in enumerate(test_dataset):
        input_ids = item['tokens']
        true_label_ids = item['ner_tags']

        predicted_ids = classify_function(input_ids)
        predicted_labels = [id2label[pid] for pid in predicted_ids]

        true_labels_cleaned = [id2label[lid] for lid in true_label_ids if lid != -100]

        tokens = item.get("tokens_str", None)
        if tokens is None:
            tokens = [str(t) for t in input_ids]

        for t, pred, true in zip(tokens, predicted_labels, true_labels_cleaned):
            if pred != "O" and true == "O":  
                false_positive_log.append((idx, t, true, pred))

        all_predictions.append(predicted_labels)
        all_true_labels.append(true_labels_cleaned)

    print("Inference complete.")

    if false_positive_log:
        print("\n===== FALSE POSITIVES FOUND =====")
        for sample_idx, token, true_label, pred_label in false_positive_log:
            print(f"[Sample {sample_idx}] Token: '{token}' | True: {true_label} | Pred: {pred_label}")
    else:
        print("\nNo false positives detected.")

    # --- Compute Metrics ---
    print("Calculating metrics...")
    results = ner_metric.compute(predictions=all_predictions, references=all_true_labels)
    return results

# %%
print(evaluate_model(test_ds, classify_text))
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# Running inference on 50 items...
# Inference complete.
#
# ===== FALSE POSITIVES FOUND =====
# [Sample 0] Token: 'Ігнатенка' | True: O | Pred: B-PERS
# [Sample 0] Token: 'В' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'М' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'Карпенко' | True: O | Pred: B-PERS
# [Sample 0] Token: 'С' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'О' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'Фаловської' | True: O | Pred: I-PERS
# [Sample 0] Token: 'І' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'М' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'В' | True: O | Pred: B-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'М' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'Ігнатенко' | True: O | Pred: I-PERS
# [Sample 0] Token: 'С' | True: O | Pred: B-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'О' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'Карпенко' | True: O | Pred: I-PERS
# [Sample 0] Token: 'І' | True: O | Pred: B-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'М' | True: O | Pred: I-PERS
# [Sample 0] Token: '.' | True: O | Pred: I-PERS
# [Sample 0] Token: 'Фаловська' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Ігнатенка' | True: O | Pred: B-PERS
# [Sample 1] Token: 'В' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'М' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Карпенко' | True: O | Pred: B-PERS
# [Sample 1] Token: 'С' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'О' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Фаловської' | True: O | Pred: I-PERS
# [Sample 1] Token: 'І' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'М' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Павлова' | True: O | Pred: B-PERS
# [Sample 1] Token: 'Ольга' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Вячеславівна' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Павлова' | True: O | Pred: B-PERS
# [Sample 1] Token: 'О' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'В' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Павлова' | True: O | Pred: B-PERS
# [Sample 1] Token: 'Ольга' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Вячеславівна' | True: O | Pred: I-PERS
# [Sample 1] Token: 'В' | True: O | Pred: B-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'М' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Ігнатенко' | True: O | Pred: I-PERS
# [Sample 1] Token: 'С' | True: O | Pred: B-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'О' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Карпенко' | True: O | Pred: I-PERS
# [Sample 1] Token: 'І' | True: O | Pred: B-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'М' | True: O | Pred: I-PERS
# [Sample 1] Token: '.' | True: O | Pred: I-PERS
# [Sample 1] Token: 'Фаловська' | True: O | Pred: I-PERS
# [Sample 7] Token: '' | True: O | Pred: B-PERS
# [Sample 10] Token: 'Сердюка' | True: O | Pred: B-PERS
# [Sample 10] Token: 'В' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'В' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'Карпенко' | True: O | Pred: B-PERS
# [Sample 10] Token: 'С' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'О' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'Фаловської' | True: O | Pred: B-PERS
# [Sample 10] Token: 'І' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'М' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'В' | True: O | Pred: B-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'В' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'Сердюк' | True: O | Pred: I-PERS
# [Sample 10] Token: 'С' | True: O | Pred: B-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'О' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'Карпенко' | True: O | Pred: I-PERS
# [Sample 10] Token: 'І' | True: O | Pred: B-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'М' | True: O | Pred: I-PERS
# [Sample 10] Token: '.' | True: O | Pred: I-PERS
# [Sample 10] Token: 'Фаловська' | True: O | Pred: I-PERS
# [Sample 10] Token: '' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Крата' | True: O | Pred: B-PERS
# [Sample 11] Token: 'В' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'І' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Дундар' | True: O | Pred: B-PERS
# [Sample 11] Token: 'І' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'О' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Краснощокова' | True: O | Pred: B-PERS
# [Sample 11] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'В' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Шмалько' | True: O | Pred: B-PERS
# [Sample 11] Token: 'Олександр' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Олександрович' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Бригіда' | True: O | Pred: B-PERS
# [Sample 11] Token: 'Володимир' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Олександрович' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Самойленка' | True: O | Pred: B-PERS
# [Sample 11] Token: 'А' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'В' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Самойленка' | True: O | Pred: B-PERS
# [Sample 11] Token: 'А' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'В' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Шмалько' | True: O | Pred: B-PERS
# [Sample 11] Token: 'Олександр' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Олександрович' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Бригіда' | True: O | Pred: B-PERS
# [Sample 11] Token: 'Володимир' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Олександрович' | True: O | Pred: I-PERS
# [Sample 11] Token: 'В' | True: O | Pred: B-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'І' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Крат' | True: O | Pred: I-PERS
# [Sample 11] Token: 'І' | True: O | Pred: B-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'О' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Дундар' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Є' | True: O | Pred: B-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'В' | True: O | Pred: I-PERS
# [Sample 11] Token: '.' | True: O | Pred: I-PERS
# [Sample 11] Token: 'Краснощоков' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Тітова' | True: O | Pred: B-PERS
# [Sample 12] Token: 'М' | True: O | Pred: I-PERS
# [Sample 12] Token: '.' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 12] Token: '.' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Корсун' | True: O | Pred: B-PERS
# [Sample 12] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 12] Token: '.' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 12] Token: '.' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Корсун' | True: O | Pred: B-PERS
# [Sample 12] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 12] Token: '.' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 12] Token: '.' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Корсуна' | True: O | Pred: B-PERS
# [Sample 12] Token: 'Юрія' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Юрійовича' | True: O | Pred: I-PERS
# [Sample 12] Token: 'М' | True: O | Pred: B-PERS
# [Sample 12] Token: '.' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 12] Token: '.' | True: O | Pred: I-PERS
# [Sample 12] Token: 'Тітов' | True: O | Pred: I-PERS
# [Sample 12] Token: '' | True: O | Pred: I-PERS
# [Sample 13] Token: 'Тітова' | True: O | Pred: B-PERS
# [Sample 13] Token: 'М' | True: O | Pred: I-PERS
# [Sample 13] Token: '.' | True: O | Pred: I-PERS
# [Sample 13] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 13] Token: '.' | True: O | Pred: I-PERS
# [Sample 13] Token: 'Дарчука' | True: O | Pred: B-PERS
# [Sample 13] Token: 'Дмитра' | True: O | Pred: I-PERS
# [Sample 13] Token: 'Вікторовича' | True: O | Pred: I-PERS
# [Sample 13] Token: 'Дарчука' | True: O | Pred: B-PERS
# [Sample 13] Token: 'Д' | True: O | Pred: I-PERS
# [Sample 13] Token: '.' | True: O | Pred: I-PERS
# [Sample 13] Token: 'В' | True: O | Pred: I-PERS
# [Sample 13] Token: '.' | True: O | Pred: I-PERS
# [Sample 13] Token: 'Дарчук' | True: O | Pred: B-PERS
# [Sample 13] Token: 'Д' | True: O | Pred: I-PERS
# [Sample 13] Token: '.' | True: O | Pred: I-PERS
# [Sample 13] Token: 'В' | True: O | Pred: I-PERS
# [Sample 13] Token: '.' | True: O | Pred: I-PERS
# [Sample 13] Token: 'М' | True: O | Pred: B-PERS
# [Sample 13] Token: '.' | True: O | Pred: I-PERS
# [Sample 13] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 13] Token: '.' | True: O | Pred: I-PERS
# [Sample 13] Token: 'Тітов' | True: O | Pred: I-PERS
# [Sample 14] Token: '' | True: O | Pred: B-PERS
# [Sample 16] Token: 'Кравчука' | True: O | Pred: B-PERS
# [Sample 16] Token: 'В' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'М' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Чиркіна' | True: O | Pred: B-PERS
# [Sample 16] Token: 'С' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'М' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Шарапи' | True: O | Pred: B-PERS
# [Sample 16] Token: 'В' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'М' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Єфіменко' | True: O | Pred: B-PERS
# [Sample 16] Token: 'О' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'В' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Боровицького' | True: O | Pred: B-PERS
# [Sample 16] Token: 'О' | True: O | Pred: B-PERS
# [Sample 16] Token: 'А' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Шидловського' | True: O | Pred: B-PERS
# [Sample 16] Token: 'В' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Б' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Курка' | True: O | Pred: B-PERS
# [Sample 16] Token: 'О' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'П' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'В' | True: O | Pred: B-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'М' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Кравчук' | True: O | Pred: I-PERS
# [Sample 16] Token: 'С' | True: O | Pred: B-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'М' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Чиркін' | True: O | Pred: I-PERS
# [Sample 16] Token: 'В' | True: O | Pred: B-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'М' | True: O | Pred: I-PERS
# [Sample 16] Token: '.' | True: O | Pred: I-PERS
# [Sample 16] Token: 'Шарапа' | True: O | Pred: I-PERS
# [Sample 16] Token: '' | True: O | Pred: I-PERS
# [Sample 17] Token: 'Кашпур' | True: O | Pred: B-PERS
# [Sample 17] Token: 'О' | True: O | Pred: I-PERS
# [Sample 17] Token: '.' | True: O | Pred: I-PERS
# [Sample 17] Token: 'В' | True: O | Pred: I-PERS
# [Sample 17] Token: '.' | True: O | Pred: I-PERS
# [Sample 17] Token: 'Ольга' | True: O | Pred: B-PERS
# [Sample 17] Token: 'КАШПУР' | True: O | Pred: I-PERS
# [Sample 18] Token: 'Смоковича' | True: O | Pred: B-PERS
# [Sample 18] Token: 'М' | True: O | Pred: I-PERS
# [Sample 18] Token: '.' | True: O | Pred: I-PERS
# [Sample 18] Token: 'І' | True: O | Pred: I-PERS
# [Sample 18] Token: '.' | True: O | Pred: I-PERS
# [Sample 18] Token: 'Дяченка' | True: O | Pred: B-PERS
# [Sample 18] Token: 'Олексія' | True: O | Pred: I-PERS
# [Sample 18] Token: 'Володимировича' | True: O | Pred: I-PERS
# [Sample 18] Token: 'Дяченком' | True: O | Pred: B-PERS
# [Sample 18] Token: 'Олексієм' | True: O | Pred: I-PERS
# [Sample 18] Token: 'Володимировичем' | True: O | Pred: I-PERS
# [Sample 18] Token: 'Дяченка' | True: O | Pred: B-PERS
# [Sample 18] Token: 'Олексія' | True: O | Pred: I-PERS
# [Sample 18] Token: 'Володимировича' | True: O | Pred: I-PERS
# [Sample 18] Token: 'М' | True: O | Pred: B-PERS
# [Sample 18] Token: '.' | True: O | Pred: I-PERS
# [Sample 18] Token: 'І' | True: O | Pred: I-PERS
# [Sample 18] Token: '.' | True: O | Pred: I-PERS
# [Sample 18] Token: 'Смокович' | True: O | Pred: I-PERS
# [Sample 19] Token: 'Шишова' | True: O | Pred: B-PERS
# [Sample 19] Token: 'О' | True: O | Pred: I-PERS
# [Sample 19] Token: '.' | True: O | Pred: I-PERS
# [Sample 19] Token: 'О' | True: O | Pred: I-PERS
# [Sample 19] Token: '.' | True: O | Pred: I-PERS
# [Sample 19] Token: 'О' | True: O | Pred: B-PERS
# [Sample 19] Token: '.' | True: O | Pred: I-PERS
# [Sample 19] Token: 'О' | True: O | Pred: I-PERS
# [Sample 19] Token: '.' | True: O | Pred: I-PERS
# [Sample 19] Token: 'Шишов' | True: O | Pred: I-PERS
# [Sample 20] Token: 'Рибачука' | True: O | Pred: B-PERS
# [Sample 20] Token: 'А' | True: O | Pred: I-PERS
# [Sample 20] Token: '.' | True: O | Pred: I-PERS
# [Sample 20] Token: 'І' | True: O | Pred: I-PERS
# [Sample 20] Token: 'Стеценка' | True: O | Pred: B-PERS
# [Sample 20] Token: 'С' | True: O | Pred: I-PERS
# [Sample 20] Token: '.' | True: O | Pred: I-PERS
# [Sample 20] Token: 'Г' | True: O | Pred: I-PERS
# [Sample 20] Token: '.' | True: O | Pred: I-PERS
# [Sample 20] Token: 'Шарапи' | True: O | Pred: B-PERS
# [Sample 20] Token: 'В' | True: O | Pred: I-PERS
# [Sample 20] Token: '.' | True: O | Pred: I-PERS
# [Sample 20] Token: 'М' | True: O | Pred: I-PERS
# [Sample 20] Token: '.' | True: O | Pred: I-PERS
# [Sample 20] Token: '.' | True: O | Pred: B-PERS
# [Sample 20] Token: 'І' | True: O | Pred: B-PERS
# [Sample 20] Token: '.' | True: O | Pred: I-PERS
# [Sample 20] Token: 'Рибачук' | True: O | Pred: I-PERS
# [Sample 20] Token: 'С' | True: O | Pred: B-PERS
# [Sample 20] Token: 'Г' | True: O | Pred: B-PERS
# [Sample 20] Token: 'Стеценко' | True: O | Pred: I-PERS
# [Sample 20] Token: 'В' | True: O | Pred: B-PERS
# [Sample 20] Token: 'М' | True: O | Pred: B-PERS
# [Sample 20] Token: '.' | True: O | Pred: I-PERS
# [Sample 20] Token: 'Шарапа' | True: O | Pred: I-PERS
# [Sample 21] Token: 'Смоковича' | True: O | Pred: B-PERS
# [Sample 21] Token: 'М' | True: O | Pred: I-PERS
# [Sample 21] Token: '.' | True: O | Pred: I-PERS
# [Sample 21] Token: 'І' | True: O | Pred: I-PERS
# [Sample 21] Token: '.' | True: O | Pred: I-PERS
# [Sample 21] Token: 'М' | True: O | Pred: B-PERS
# [Sample 21] Token: '.' | True: O | Pred: I-PERS
# [Sample 21] Token: 'І' | True: O | Pred: I-PERS
# [Sample 21] Token: '.' | True: O | Pred: I-PERS
# [Sample 21] Token: 'Смокович' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Смоковича' | True: O | Pred: I-PERS
# [Sample 22] Token: 'М' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'І' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Мацедонської' | True: O | Pred: I-PERS
# [Sample 22] Token: 'В' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Радишевської' | True: O | Pred: I-PERS
# [Sample 22] Token: 'О' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'М' | True: O | Pred: B-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'І' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Смокович' | True: O | Pred: I-PERS
# [Sample 22] Token: 'В' | True: O | Pred: B-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Мацедонська' | True: O | Pred: I-PERS
# [Sample 22] Token: 'О' | True: O | Pred: B-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 22] Token: '.' | True: O | Pred: I-PERS
# [Sample 22] Token: 'Радишевська' | True: O | Pred: I-PERS
# [Sample 22] Token: '' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Смоковича' | True: O | Pred: I-PERS
# [Sample 23] Token: 'М' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'І' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Мацедонської' | True: O | Pred: I-PERS
# [Sample 23] Token: 'В' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Радишевської' | True: O | Pred: I-PERS
# [Sample 23] Token: 'О' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'М' | True: O | Pred: B-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'І' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Смокович' | True: O | Pred: I-PERS
# [Sample 23] Token: 'В' | True: O | Pred: B-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Мацедонська' | True: O | Pred: I-PERS
# [Sample 23] Token: 'О' | True: O | Pred: B-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 23] Token: '.' | True: O | Pred: I-PERS
# [Sample 23] Token: 'Радишевська' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Смоковича' | True: O | Pred: B-PERS
# [Sample 24] Token: 'М' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'І' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Мацедонської' | True: O | Pred: B-PERS
# [Sample 24] Token: 'В' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Радишевської' | True: O | Pred: I-PERS
# [Sample 24] Token: 'О' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Мандрика' | True: O | Pred: B-PERS
# [Sample 24] Token: 'Владислава' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Володимировича' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Мандрика' | True: O | Pred: B-PERS
# [Sample 24] Token: 'Владислава' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Володимировича' | True: O | Pred: I-PERS
# [Sample 24] Token: 'М' | True: O | Pred: B-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'І' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Смокович' | True: O | Pred: I-PERS
# [Sample 24] Token: 'В' | True: O | Pred: B-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Мацедонська' | True: O | Pred: I-PERS
# [Sample 24] Token: 'О' | True: O | Pred: B-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 24] Token: '.' | True: O | Pred: I-PERS
# [Sample 24] Token: 'Радишевська' | True: O | Pred: I-PERS
# [Sample 25] Token: 'Смоковича' | True: O | Pred: B-PERS
# [Sample 25] Token: 'М' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'І' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'Мацедонської' | True: O | Pred: B-PERS
# [Sample 25] Token: 'В' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'Уханенка' | True: O | Pred: B-PERS
# [Sample 25] Token: 'С' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'А' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'М' | True: O | Pred: B-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'І' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'Смокович' | True: O | Pred: I-PERS
# [Sample 25] Token: 'В' | True: O | Pred: B-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'Мацедонська' | True: O | Pred: I-PERS
# [Sample 25] Token: 'С' | True: O | Pred: B-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'А' | True: O | Pred: I-PERS
# [Sample 25] Token: '.' | True: O | Pred: I-PERS
# [Sample 25] Token: 'Уханенко' | True: O | Pred: I-PERS
# [Sample 26] Token: 'Смоковича' | True: O | Pred: I-PERS
# [Sample 26] Token: 'М' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'І' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'Мацедонської' | True: O | Pred: I-PERS
# [Sample 26] Token: 'В' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'Уханенка' | True: O | Pred: I-PERS
# [Sample 26] Token: 'С' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'А' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'М' | True: O | Pred: B-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'І' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'Смокович' | True: O | Pred: I-PERS
# [Sample 26] Token: 'В' | True: O | Pred: B-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'Е' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'Мацедонська' | True: O | Pred: I-PERS
# [Sample 26] Token: 'С' | True: O | Pred: B-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'А' | True: O | Pred: I-PERS
# [Sample 26] Token: '.' | True: O | Pred: I-PERS
# [Sample 26] Token: 'Уханенко' | True: O | Pred: I-PERS
# [Sample 27] Token: 'Уханенка' | True: O | Pred: B-PERS
# [Sample 27] Token: 'С' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'А' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'Кашпур' | True: O | Pred: B-PERS
# [Sample 27] Token: 'О' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'В' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'Мельник-Томенко' | True: O | Pred: B-PERS
# [Sample 27] Token: 'Ж' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'М' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'С' | True: O | Pred: B-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'А' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'Уханенко' | True: O | Pred: I-PERS
# [Sample 27] Token: 'О' | True: O | Pred: B-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'В' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'Кашпур' | True: O | Pred: I-PERS
# [Sample 27] Token: 'Ж' | True: O | Pred: B-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'М' | True: O | Pred: I-PERS
# [Sample 27] Token: '.' | True: O | Pred: I-PERS
# [Sample 27] Token: 'Мельник-Томенко' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Уханенка' | True: O | Pred: B-PERS
# [Sample 28] Token: 'С' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'А' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Кашпур' | True: O | Pred: B-PERS
# [Sample 28] Token: 'О' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'В' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Мельник-Томенко' | True: O | Pred: B-PERS
# [Sample 28] Token: 'Ж' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'М' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: '-' | True: O | Pred: B-PERS
# [Sample 28] Token: 'Дзундзи' | True: O | Pred: B-PERS
# [Sample 28] Token: 'Юрія' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Романовича' | True: O | Pred: I-PERS
# [Sample 28] Token: '-' | True: O | Pred: B-PERS
# [Sample 28] Token: 'Дзундзи' | True: O | Pred: B-PERS
# [Sample 28] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: '-' | True: O | Pred: B-PERS
# [Sample 28] Token: 'Дзундза' | True: O | Pred: B-PERS
# [Sample 28] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: '-' | True: O | Pred: B-PERS
# [Sample 28] Token: 'Дзундзи' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Юрія' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Романовича' | True: O | Pred: I-PERS
# [Sample 28] Token: 'С' | True: O | Pred: B-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'А' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Уханенко' | True: O | Pred: I-PERS
# [Sample 28] Token: 'О' | True: O | Pred: B-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'В' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Кашпур' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Ж' | True: O | Pred: B-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'М' | True: O | Pred: I-PERS
# [Sample 28] Token: '.' | True: O | Pred: I-PERS
# [Sample 28] Token: 'Мельник-Томенко' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Крата' | True: O | Pred: B-PERS
# [Sample 29] Token: 'В' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'І' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Дундар' | True: O | Pred: B-PERS
# [Sample 29] Token: 'І' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'О' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Краснощокова' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'В' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Маловічко' | True: O | Pred: B-PERS
# [Sample 29] Token: 'С' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'В' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Гончар' | True: O | Pred: B-PERS
# [Sample 29] Token: 'М' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'С' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Подліянової' | True: O | Pred: B-PERS
# [Sample 29] Token: 'Г' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'С' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Машкіної' | True: O | Pred: B-PERS
# [Sample 29] Token: 'Н' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'В' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Крату' | True: O | Pred: B-PERS
# [Sample 29] Token: 'В' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'І' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'В' | True: O | Pred: B-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'І' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Крат' | True: O | Pred: I-PERS
# [Sample 29] Token: 'І' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'О' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Дундар' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: '.' | True: O | Pred: I-PERS
# [Sample 29] Token: 'Краснощоков' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Тітова' | True: O | Pred: B-PERS
# [Sample 30] Token: 'М' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Бойка' | True: O | Pred: B-PERS
# [Sample 30] Token: 'Артура' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Миколайовича' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Бойка' | True: O | Pred: B-PERS
# [Sample 30] Token: 'А' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'М' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Бойко' | True: O | Pred: B-PERS
# [Sample 30] Token: 'А' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'М' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Бойка' | True: O | Pred: B-PERS
# [Sample 30] Token: 'А' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'М' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Бойка' | True: O | Pred: B-PERS
# [Sample 30] Token: 'Артура' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Миколайовича' | True: O | Pred: I-PERS
# [Sample 30] Token: 'М' | True: O | Pred: B-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 30] Token: '.' | True: O | Pred: I-PERS
# [Sample 30] Token: 'Тітов' | True: O | Pred: I-PERS
# [Sample 31] Token: 'Литвиненко' | True: O | Pred: B-PERS
# [Sample 31] Token: 'І' | True: O | Pred: I-PERS
# [Sample 31] Token: '.' | True: O | Pred: I-PERS
# [Sample 31] Token: 'В' | True: O | Pred: I-PERS
# [Sample 31] Token: '.' | True: O | Pred: I-PERS
# [Sample 31] Token: 'Ніна' | True: O | Pred: B-PERS
# [Sample 31] Token: 'Ігорівна' | True: O | Pred: I-PERS
# [Sample 31] Token: 'Ніна' | True: O | Pred: B-PERS
# [Sample 31] Token: 'Ігорівна' | True: O | Pred: I-PERS
# [Sample 31] Token: 'Ніна' | True: O | Pred: B-PERS
# [Sample 31] Token: 'Ігорівна' | True: O | Pred: I-PERS
# [Sample 31] Token: 'Варяничко' | True: O | Pred: B-PERS
# [Sample 31] Token: 'С' | True: O | Pred: I-PERS
# [Sample 31] Token: '.' | True: O | Pred: I-PERS
# [Sample 31] Token: 'В' | True: O | Pred: I-PERS
# [Sample 31] Token: '.' | True: O | Pred: I-PERS
# [Sample 31] Token: ',' | True: O | Pred: I-PERS
# [Sample 31] Token: 'І' | True: O | Pred: B-PERS
# [Sample 31] Token: '.' | True: O | Pred: I-PERS
# [Sample 31] Token: 'В' | True: O | Pred: I-PERS
# [Sample 31] Token: '.' | True: O | Pred: I-PERS
# [Sample 31] Token: 'Литвиненко' | True: O | Pred: I-PERS
# [Sample 32] Token: 'О' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'М' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Гриценка' | True: O | Pred: B-PERS
# [Sample 32] Token: 'Віталія' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Євгеновича' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Карімовою' | True: O | Pred: B-PERS
# [Sample 32] Token: 'Л' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'М' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Карімовою' | True: O | Pred: B-PERS
# [Sample 32] Token: 'Л' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'М' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Гриценка' | True: O | Pred: B-PERS
# [Sample 32] Token: 'В' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Гриценка' | True: O | Pred: B-PERS
# [Sample 32] Token: 'Віталія' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Євгеновича' | True: O | Pred: I-PERS
# [Sample 32] Token: 'О' | True: O | Pred: B-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'М' | True: O | Pred: I-PERS
# [Sample 32] Token: '.' | True: O | Pred: I-PERS
# [Sample 32] Token: 'Осіян' | True: O | Pred: I-PERS
# [Sample 33] Token: 'Рибачука' | True: O | Pred: I-PERS
# [Sample 33] Token: 'А' | True: O | Pred: I-PERS
# [Sample 33] Token: '.' | True: O | Pred: I-PERS
# [Sample 33] Token: 'І' | True: O | Pred: I-PERS
# [Sample 33] Token: 'Бучик' | True: O | Pred: I-PERS
# [Sample 33] Token: 'А' | True: O | Pred: I-PERS
# [Sample 33] Token: '.' | True: O | Pred: I-PERS
# [Sample 33] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 33] Token: '.' | True: O | Pred: I-PERS
# [Sample 33] Token: 'Стрелець' | True: O | Pred: I-PERS
# [Sample 33] Token: 'Т' | True: O | Pred: I-PERS
# [Sample 33] Token: '.' | True: O | Pred: I-PERS
# [Sample 33] Token: 'Г' | True: O | Pred: I-PERS
# [Sample 33] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Кравчука' | True: O | Pred: B-PERS
# [Sample 34] Token: 'В' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'М' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Берназюка' | True: O | Pred: B-PERS
# [Sample 34] Token: 'Я' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'О' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Шарапи' | True: O | Pred: B-PERS
# [Sample 34] Token: 'В' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'М' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Любчич' | True: O | Pred: B-PERS
# [Sample 34] Token: 'Л' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'В' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Присяжнюк' | True: O | Pred: B-PERS
# [Sample 34] Token: 'О' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'В' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Спаскіна' | True: O | Pred: B-PERS
# [Sample 34] Token: 'О' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'А' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'В' | True: O | Pred: B-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'М' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Кравчук' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Я' | True: O | Pred: B-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'О' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Берназюк' | True: O | Pred: I-PERS
# [Sample 34] Token: 'В' | True: O | Pred: B-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'М' | True: O | Pred: I-PERS
# [Sample 34] Token: '.' | True: O | Pred: I-PERS
# [Sample 34] Token: 'Шарапа' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Кравчука' | True: O | Pred: B-PERS
# [Sample 35] Token: 'В' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'М' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Берназюка' | True: O | Pred: B-PERS
# [Sample 35] Token: 'Я' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'О' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Шарапи' | True: O | Pred: B-PERS
# [Sample 35] Token: 'В' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'М' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Цховребова' | True: O | Pred: B-PERS
# [Sample 35] Token: 'М' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Г' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Танасогло' | True: O | Pred: B-PERS
# [Sample 35] Token: 'Т' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'М' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Димерлія' | True: O | Pred: B-PERS
# [Sample 35] Token: 'О' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'О' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Крусяна' | True: O | Pred: B-PERS
# [Sample 35] Token: 'А' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'В' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'В' | True: O | Pred: B-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'М' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Кравчук' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Я' | True: O | Pred: B-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'О' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Берназюк' | True: O | Pred: I-PERS
# [Sample 35] Token: 'В' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'М' | True: O | Pred: I-PERS
# [Sample 35] Token: '.' | True: O | Pred: I-PERS
# [Sample 35] Token: 'Шарапа' | True: O | Pred: I-PERS
# [Sample 36] Token: 'Ігнатенка' | True: O | Pred: B-PERS
# [Sample 36] Token: 'В' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'М' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'Литвиненко' | True: O | Pred: B-PERS
# [Sample 36] Token: 'І' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'В' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'Олійник' | True: O | Pred: B-PERS
# [Sample 36] Token: 'А' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'С' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'В' | True: O | Pred: B-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'М' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'Ігнатенко' | True: O | Pred: I-PERS
# [Sample 36] Token: 'І' | True: O | Pred: B-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'В' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'Литвиненко' | True: O | Pred: I-PERS
# [Sample 36] Token: 'А' | True: O | Pred: B-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'С' | True: O | Pred: I-PERS
# [Sample 36] Token: '.' | True: O | Pred: I-PERS
# [Sample 36] Token: 'Олійник' | True: O | Pred: I-PERS
# [Sample 36] Token: '' | True: O | Pred: I-PERS
# [Sample 37] Token: 'Синельникова' | True: O | Pred: B-PERS
# [Sample 37] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'В' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'Осіяна' | True: O | Pred: B-PERS
# [Sample 37] Token: 'О' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'М' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'Шиповича' | True: O | Pred: I-PERS
# [Sample 37] Token: 'В' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'В' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'Є' | True: O | Pred: B-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'В' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'Синельников' | True: O | Pred: I-PERS
# [Sample 37] Token: 'О' | True: O | Pred: B-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'М' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'Осіян' | True: O | Pred: I-PERS
# [Sample 37] Token: 'В' | True: O | Pred: B-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'В' | True: O | Pred: I-PERS
# [Sample 37] Token: '.' | True: O | Pred: I-PERS
# [Sample 37] Token: 'Шипович' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Грушицького' | True: O | Pred: I-PERS
# [Sample 38] Token: 'А' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'І' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Литвиненко' | True: O | Pred: B-PERS
# [Sample 38] Token: 'І' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'В' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Петрова' | True: O | Pred: B-PERS
# [Sample 38] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'В' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Таранка' | True: O | Pred: B-PERS
# [Sample 38] Token: 'Дмитра' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Вікторовича' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Таранко' | True: O | Pred: B-PERS
# [Sample 38] Token: 'Д' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'В' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Таранка' | True: O | Pred: B-PERS
# [Sample 38] Token: 'Д' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'В' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Таранка' | True: O | Pred: B-PERS
# [Sample 38] Token: 'Дмитра' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Вікторовича' | True: O | Pred: I-PERS
# [Sample 38] Token: 'А' | True: O | Pred: B-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'І' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Грушицький' | True: O | Pred: I-PERS
# [Sample 38] Token: 'І' | True: O | Pred: B-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'В' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Литвиненко' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Є' | True: O | Pred: B-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'В' | True: O | Pred: I-PERS
# [Sample 38] Token: '.' | True: O | Pred: I-PERS
# [Sample 38] Token: 'Петров' | True: O | Pred: I-PERS
# [Sample 38] Token: '' | True: O | Pred: I-PERS
# [Sample 39] Token: 'Грушицького' | True: O | Pred: B-PERS
# [Sample 39] Token: 'А' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'І' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'Литвиненко' | True: O | Pred: B-PERS
# [Sample 39] Token: 'І' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'В' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'Петрова' | True: O | Pred: B-PERS
# [Sample 39] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'В' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'Бруалья' | True: O | Pred: B-PERS
# [Sample 39] Token: 'Ґомес' | True: O | Pred: I-PERS
# [Sample 39] Token: 'А' | True: O | Pred: B-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'І' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'Грушицький' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'В' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'Литвиненко' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'В' | True: O | Pred: I-PERS
# [Sample 39] Token: '.' | True: O | Pred: I-PERS
# [Sample 39] Token: 'Петров' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Грушицького' | True: O | Pred: I-PERS
# [Sample 40] Token: 'А' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'І' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Литвиненко' | True: O | Pred: B-PERS
# [Sample 40] Token: 'І' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'В' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Петрова' | True: O | Pred: B-PERS
# [Sample 40] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'В' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Д' | True: O | Pred: B-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Л' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'А' | True: O | Pred: B-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'І' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Грушицький' | True: O | Pred: I-PERS
# [Sample 40] Token: 'І' | True: O | Pred: B-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'В' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Литвиненко' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Є' | True: O | Pred: B-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'В' | True: O | Pred: I-PERS
# [Sample 40] Token: '.' | True: O | Pred: I-PERS
# [Sample 40] Token: 'Петров' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Петрова' | True: O | Pred: B-PERS
# [Sample 41] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'В' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Грушицького' | True: O | Pred: B-PERS
# [Sample 41] Token: 'А' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'І' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Литвиненко' | True: O | Pred: B-PERS
# [Sample 41] Token: 'І' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'В' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Олійник' | True: O | Pred: B-PERS
# [Sample 41] Token: 'А' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'С' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Ступак' | True: O | Pred: B-PERS
# [Sample 41] Token: 'О' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'В' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Петрову' | True: O | Pred: B-PERS
# [Sample 41] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'В' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Грушицький' | True: O | Pred: B-PERS
# [Sample 41] Token: 'А' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'І' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Литвиненко' | True: O | Pred: B-PERS
# [Sample 41] Token: 'І' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'В' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Є' | True: O | Pred: B-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'В' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Петров' | True: O | Pred: I-PERS
# [Sample 41] Token: 'А' | True: O | Pred: B-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'І' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Грушицький' | True: O | Pred: I-PERS
# [Sample 41] Token: 'І' | True: O | Pred: B-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'В' | True: O | Pred: I-PERS
# [Sample 41] Token: '.' | True: O | Pred: I-PERS
# [Sample 41] Token: 'Литвиненко' | True: O | Pred: I-PERS
# [Sample 42] Token: 'О' | True: O | Pred: B-PERS
# [Sample 42] Token: '.' | True: O | Pred: I-PERS
# [Sample 42] Token: 'В' | True: O | Pred: I-PERS
# [Sample 42] Token: '.' | True: O | Pred: I-PERS
# [Sample 42] Token: 'О' | True: O | Pred: B-PERS
# [Sample 42] Token: '.' | True: O | Pred: I-PERS
# [Sample 42] Token: 'В' | True: O | Pred: I-PERS
# [Sample 42] Token: '.' | True: O | Pred: I-PERS
# [Sample 42] Token: 'Білоконь' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Русинчука' | True: O | Pred: I-PERS
# [Sample 43] Token: 'М' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'М' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Гудими' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Д' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'А' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Краснощокова' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'В' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Михайлова' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Наталія' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Олександрівна' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Павловою' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Надією' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Євгенівною' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Березовенко' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'В' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Лапчевської' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Мостової' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Г' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'І' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Михайлова' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Наталія' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Олександрівна' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Михайлова' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Н' | True: O | Pred: B-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'О' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Нещадимом' | True: O | Pred: B-PERS
# [Sample 43] Token: 'І' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'С' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Ярушевською' | True: O | Pred: I-PERS
# [Sample 43] Token: 'І' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'І' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Михайловою' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Н' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'М' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Павлова' | True: O | Pred: B-PERS
# [Sample 43] Token: 'Н' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'М' | True: O | Pred: B-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'М' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Русинчук' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Д' | True: O | Pred: B-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'А' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Гудима' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Є' | True: O | Pred: B-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'В' | True: O | Pred: I-PERS
# [Sample 43] Token: '.' | True: O | Pred: I-PERS
# [Sample 43] Token: 'Краснощоков' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Грушицького' | True: O | Pred: B-PERS
# [Sample 44] Token: 'А' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'І' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Литвиненко' | True: O | Pred: B-PERS
# [Sample 44] Token: 'І' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'В' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Петрова' | True: O | Pred: B-PERS
# [Sample 44] Token: 'Є' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'В' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Леваж' | True: O | Pred: B-PERS
# [Sample 44] Token: 'Престасьон' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Бруалья' | True: O | Pred: B-PERS
# [Sample 44] Token: 'Ґомес' | True: O | Pred: I-PERS
# [Sample 44] Token: 'А' | True: O | Pred: B-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'І' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Грушицький' | True: O | Pred: I-PERS
# [Sample 44] Token: 'І' | True: O | Pred: B-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'В' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Литвиненко' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Є' | True: O | Pred: B-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'В' | True: O | Pred: I-PERS
# [Sample 44] Token: '.' | True: O | Pred: I-PERS
# [Sample 44] Token: 'Петров' | True: O | Pred: I-PERS
# [Sample 44] Token: '' | True: O | Pred: I-PERS
# [Sample 45] Token: 'Сакари' | True: O | Pred: B-PERS
# [Sample 45] Token: 'Н' | True: O | Pred: I-PERS
# [Sample 45] Token: '.' | True: O | Pred: I-PERS
# [Sample 45] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 45] Token: '.' | True: O | Pred: I-PERS
# [Sample 45] Token: 'Н' | True: O | Pred: I-PERS
# [Sample 45] Token: '.' | True: O | Pred: I-PERS
# [Sample 45] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 45] Token: '.' | True: O | Pred: I-PERS
# [Sample 45] Token: 'Сакара' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Н' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Ситцевой' | True: O | Pred: B-PERS
# [Sample 46] Token: 'Валерія' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Васильовича' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Ситцевой' | True: O | Pred: B-PERS
# [Sample 46] Token: 'В' | True: O | Pred: I-PERS
# [Sample 46] Token: '.' | True: O | Pred: I-PERS
# [Sample 46] Token: 'В' | True: O | Pred: I-PERS
# [Sample 46] Token: '.' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Ситцевой' | True: O | Pred: B-PERS
# [Sample 46] Token: 'Валерія' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Васильовича' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Н' | True: O | Pred: I-PERS
# [Sample 46] Token: '.' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Ю' | True: O | Pred: I-PERS
# [Sample 46] Token: '.' | True: O | Pred: I-PERS
# [Sample 46] Token: 'Сакара' | True: O | Pred: I-PERS
# [Sample 46] Token: '' | True: O | Pred: I-PERS
# [Sample 47] Token: '' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Мартинюк' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Н' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'М' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Жука' | True: O | Pred: B-PERS
# [Sample 48] Token: 'А' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'В' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Мельник-Томенко' | True: O | Pred: B-PERS
# [Sample 48] Token: 'Ж' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'М' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Н' | True: O | Pred: B-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'М' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Мартинюк' | True: O | Pred: I-PERS
# [Sample 48] Token: 'А' | True: O | Pred: B-PERS
# [Sample 48] Token: 'В' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Жук' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Ж' | True: O | Pred: B-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'М' | True: O | Pred: I-PERS
# [Sample 48] Token: '.' | True: O | Pred: I-PERS
# [Sample 48] Token: 'Мельник-Томенко' | True: O | Pred: I-PERS
# [Sample 49] Token: 'Радишевської' | True: O | Pred: B-PERS
# [Sample 49] Token: 'О' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'Уханенка' | True: O | Pred: B-PERS
# [Sample 49] Token: 'С' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'А' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'Соколова' | True: O | Pred: B-PERS
# [Sample 49] Token: 'В' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'М' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'О' | True: O | Pred: B-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'Р' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'Радишевська' | True: O | Pred: I-PERS
# [Sample 49] Token: 'В' | True: O | Pred: B-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'М' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'Соколов' | True: O | Pred: I-PERS
# [Sample 49] Token: 'С' | True: O | Pred: B-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'А' | True: O | Pred: I-PERS
# [Sample 49] Token: '.' | True: O | Pred: I-PERS
# [Sample 49] Token: 'Уханенко' | True: O | Pred: I-PERS
# Calculating metrics...
# {'PERS': {'precision': 0.5228628230616302, 'recall': 0.8129829984544049, 'f1': 0.6364186327888687, 'number': 647}, 'overall_precision': 0.5228628230616302, 'overall_recall': 0.8129829984544049, 'overall_f1': 0.6364186327888687, 'overall_accuracy': 0.9744571204511082}

# %% [markdown]
# We can see that almost all false postives are actual personal information, that wasnt labeled as such in our test cases. It wasnt marked, becuase it wasnt initially masked in government data.

# %% [markdown]
# Overall, we have a great model, maskes identities well and thats all we need at this stage.
